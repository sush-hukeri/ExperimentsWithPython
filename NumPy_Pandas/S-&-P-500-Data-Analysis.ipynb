# %%
import pandas as pd
import re
pd.__version__
# Out:
# '0.20.2'

# %%
url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
df = pd.read_html(url, header=0, index_col=0)
components_df = df[0]
components_df.head(5)
# Out:
#                    Security SEC filings             GICS Sector  \
# Symbol
# MMM              3M Company     reports             Industrials
# ABT     Abbott Laboratories     reports             Health Care
# ABBV            AbbVie Inc.     reports             Health Care
# ACN           Accenture plc     reports  Information Technology
# ATVI    Activision Blizzard     reports  Information Technology
#
#                      GICS Sub Industry   Address of Headquarters  \
# Symbol
# MMM           Industrial Conglomerates       St. Paul, Minnesota
# ABT              Health Care Equipment   North Chicago, Illinois
# ABBV                   Pharmaceuticals   North Chicago, Illinois
# ACN     IT Consulting & Other Services           Dublin, Ireland
# ATVI       Home Entertainment Software  Santa Monica, California
#
#        Date first added      CIK
# Symbol
# MMM                 NaN    66740
# ABT          1964-03-31     1800
# ABBV         2012-12-31  1551152
# ACN          2011-07-06  1467373
# ATVI         2015-08-31   718877

# %%
# Drop columns SEC filings and CIK
components_df.drop(['SEC filings', 'CIK'], axis=1, inplace=True)
components_df.head(5)

# Convert column Date first added to a datetime column
components_df['Date first added'] = pd.to_datetime(components_df['Date first added'])

# %%
# Split Address of Headquarters into city and state
components_df[['City', 'State']] = components_df['Address of Headquarters'].str.split(',', expand=True, n=1)
components_df.State = components_df.State.str.strip()
components_df.head(5)
# Out:
#                    Security             GICS Sector  \
# Symbol
# MMM              3M Company             Industrials
# ABT     Abbott Laboratories             Health Care
# ABBV            AbbVie Inc.             Health Care
# ACN           Accenture plc  Information Technology
# ATVI    Activision Blizzard  Information Technology
#
#                      GICS Sub Industry   Address of Headquarters  \
# Symbol
# MMM           Industrial Conglomerates       St. Paul, Minnesota
# ABT              Health Care Equipment   North Chicago, Illinois
# ABBV                   Pharmaceuticals   North Chicago, Illinois
# ACN     IT Consulting & Other Services           Dublin, Ireland
# ATVI       Home Entertainment Software  Santa Monica, California
#
#        Date first added           City       State
# Symbol
# MMM                 NaT       St. Paul   Minnesota
# ABT          1964-03-31  North Chicago    Illinois
# ABBV         2012-12-31  North Chicago    Illinois
# ACN          2011-07-06         Dublin     Ireland
# ATVI         2015-08-31   Santa Monica  California

# %%
# Drop the Address of Headquarters column
components_df.drop('Address of Headquarters', axis=1, inplace=True)
components_df.head(5)
# Out:
#                    Security             GICS Sector  \
# Symbol
# MMM              3M Company             Industrials
# ABT     Abbott Laboratories             Health Care
# ABBV            AbbVie Inc.             Health Care
# ACN           Accenture plc  Information Technology
# ATVI    Activision Blizzard  Information Technology
#
#                      GICS Sub Industry Date first added           City  \
# Symbol
# MMM           Industrial Conglomerates              NaT       St. Paul
# ABT              Health Care Equipment       1964-03-31  North Chicago
# ABBV                   Pharmaceuticals       2012-12-31  North Chicago
# ACN     IT Consulting & Other Services       2011-07-06         Dublin
# ATVI       Home Entertainment Software       2015-08-31   Santa Monica
#
#              State
# Symbol
# MMM      Minnesota
# ABT       Illinois
# ABBV      Illinois
# ACN        Ireland
# ATVI    California

# %%
components_df['GICS Sector'].value_counts()
# Out:
# Consumer Discretionary        85
# Information Technology        69
# Financials                    67
# Industrials                   65
# Health Care                   61
# Consumer Staples              36
# Energy                        34
# Real Estate                   31
# Utilities                     28
# Materials                     25
# Telecommunication Services     4
# Name: GICS Sector, dtype: int64

# %%
# Most recently added to the index
components_df.loc[components_df['Date first added'].argmax()]
# Out:
# Security                 Align Technology
# GICS Sector                   Health Care
# GICS Sub Industry    Health Care Supplies
# Date first added      2017-06-19 00:00:00
# City                             San Jose
# State                          California
# Name: ALGN, dtype: object

# %%
# Added after a specific year, say, 2014
components_df.loc[components_df['Date first added'].dt.year > 2014].head(10)
# Out:
#                                    Security             GICS Sector  \
# Symbol
# ATVI                    Activision Blizzard  Information Technology
# AYI                       Acuity Brands Inc             Industrials
# AMD              Advanced Micro Devices Inc  Information Technology
# AAP                      Advance Auto Parts  Consumer Discretionary
# ALK                    Alaska Air Group Inc             Industrials
# ALB                          Albemarle Corp               Materials
# ARE     Alexandria Real Estate Equities Inc             Real Estate
# ALGN                       Align Technology             Health Care
# LNT                     Alliant Energy Corp               Utilities
# AAL                 American Airlines Group             Industrials
#
#                         GICS Sub Industry Date first added          City  \
# Symbol
# ATVI          Home Entertainment Software       2015-08-31  Santa Monica
# AYI     Electrical Components & Equipment       2016-05-03       Atlanta
# AMD                        Semiconductors       2017-03-20     Sunnyvale
# AAP                     Automotive Retail       2015-07-09       Roanoke
# ALK                              Airlines       2016-05-13       Seattle
# ALB                   Specialty Chemicals       2016-07-01   Baton Rouge
# ARE                          Office REITs       2017-03-20      Pasadena
# ALGN                 Health Care Supplies       2017-06-19      San Jose
# LNT                    Electric Utilities       2016-07-01       Madison
# AAL                              Airlines       2015-03-23    Fort Worth
#
#              State
# Symbol
# ATVI    California
# AYI        Georgia
# AMD     California
# AAP       Virginia
# ALK     Washington
# ALB      Louisiana
# ARE     California
# ALGN    California
# LNT      Wisconsin
# AAL          Texas

# %%
# Which state has the least concentration of S&P 500 companies and what are those companies?
least_represented_state = components_df.State.value_counts().argmin()
components_df.loc[components_df.State == least_represented_state]
# Out:
#                 Security             GICS Sector GICS Sub Industry  \
# Symbol
# WYNN    Wynn Resorts Ltd  Consumer Discretionary  Casinos & Gaming
#
#        Date first added       City   State
# Symbol
# WYNN         2008-11-14  Las Vegas  Nevada

# %%
# Which city serves as the headquarters of the most S&P 500 companies?
city_with_most_hqs = components_df.City.value_counts().argmax()
components_df.loc[components_df.City == city_with_most_hqs]
# Out:
#                                   Security                 GICS Sector  \
# Symbol
# AXP                    American Express Co                  Financials
# AIG     American International Group, Inc.                  Financials
# ARNC                           Arconic Inc                 Industrials
# AIZ                           Assurant Inc                  Financials
# BK       The Bank of New York Mellon Corp.                  Financials
# BLK                              BlackRock                  Financials
# BMY                   Bristol-Myers Squibb                 Health Care
# CBS                              CBS Corp.      Consumer Discretionary
# C                           Citigroup Inc.                  Financials
# COH                             Coach Inc.      Consumer Discretionary
# CL                       Colgate-Palmolive            Consumer Staples
# ED                     Consolidated Edison                   Utilities
# COTY                             Coty, Inc            Consumer Staples
# ETFC                               E*Trade                  Financials
# EL                       Estee Lauder Cos.            Consumer Staples
# FL                         Foot Locker Inc      Consumer Discretionary
# GS                     Goldman Sachs Group                  Financials
# HES                       Hess Corporation                      Energy
# IPG                      Interpublic Group      Consumer Discretionary
# IFF              Intl Flavors & Fragrances                   Materials
# JPM                   JPMorgan Chase & Co.                  Financials
# LLL            L-3 Communications Holdings                 Industrials
# LUK                Leucadia National Corp.                  Financials
# L                              Loews Corp.                  Financials
# MMC                       Marsh & McLennan                  Financials
# MET                           MetLife Inc.                  Financials
# KORS                 Michael Kors Holdings      Consumer Discretionary
# MCO                           Moody's Corp                  Financials
# MS                          Morgan Stanley                  Financials
# NDAQ                          Nasdaq, Inc.                  Financials
# NWSA                    News Corp. Class A      Consumer Discretionary
# NWS                     News Corp. Class B      Consumer Discretionary
# NLSN                      Nielsen Holdings                 Industrials
# OMC                          Omnicom Group      Consumer Discretionary
# PFE                            Pfizer Inc.                 Health Care
# PM             Philip Morris International            Consumer Staples
# RL                 Polo Ralph Lauren Corp.      Consumer Discretionary
# PVH                              PVH Corp.      Consumer Discretionary
# SLG                        SL Green Realty                 Real Estate
# SPGI                      S&P Global, Inc.                  Financials
# TIF                          Tiffany & Co.      Consumer Discretionary
# TWX                       Time Warner Inc.      Consumer Discretionary
# TRV           The Travelers Companies Inc.                  Financials
# FOXA      Twenty-First Century Fox Class A      Consumer Discretionary
# FOX       Twenty-First Century Fox Class B      Consumer Discretionary
# VZ                  Verizon Communications  Telecommunication Services
# VIAB                           Viacom Inc.      Consumer Discretionary
# VNO                   Vornado Realty Trust                 Real Estate
#
#                             GICS Sub Industry Date first added      City  \
# Symbol
# AXP                          Consumer Finance       1976-06-30  New York
# AIG             Property & Casualty Insurance       1980-03-31  New York
# ARNC                      Aerospace & Defense       1964-03-31  New York
# AIZ                      Multi-line Insurance       2007-04-10  New York
# BK           Asset Management & Custody Banks              NaT  New York
# BLK          Asset Management & Custody Banks       2011-04-04  New York
# BMY                  Health Care Distributors              NaT  New York
# CBS                              Broadcasting       1994-09-01  New York
